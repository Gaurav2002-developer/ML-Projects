# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Bank.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
df.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %%
df.isnull().sum().sum()/len(df)
# Out:
# np.float64(0.0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize = (8,6))

# %%
sns.countplot(x = 'churn' , data = df)
plt.title('Customer Churn DIstribution')
plt.xlabel('Churn (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='country', data=df, palette='coolwarm')
plt.title('Customers by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x = 'gender' , data = df)
plt.title('Gender Distribution')
plt.show()

# %%
sns.histplot(df['age'] , bins = 30 , kde = True)
plt.title('Age Distribution')
plt.show()

# %%
sns.boxplot(x = 'churn' , y = 'age' , data = df)
plt.title('Age Distribution by Churn')
plt.xlabel('Churn')
plt.ylabel('Age Distribution')
plt.show()

# %%
sns.boxplot(x = 'churn' , y = 'balance', data = df)
plt.title('Balance Distribution by Churn')
plt.xlabel('Churn')
plt.ylabel('Account Balance')
plt.show()

# %%
sns.boxplot(x = 'churn' , y = 'estimated_salary' , data = df)
plt.title('Estimated Salary vs Churn')
plt.show()

# %%
sns.boxplot(x = 'churn' , y = 'credit_score', data =df)
plt.title('Credit Score Disstribution with Churn')
plt.xlabel('Churn')
plt.ylabel('Credit Score')
plt.show()

# %%
sns.scatterplot(x = 'age' , y = 'credit_score' , hue = 'churn' , data = df, alpha = 0.7)
plt.title('Age vs Credit Score (colored by Churn)')
plt.show()

# %%
plt.figure(figsize = (10,8))
corr = df.corr(numeric_only = True)
sns.heatmap(corr , annot = True , cmap = 'coolwarm' , linewidth = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df[['credit_score', 'age', 'balance', 'estimated_salary', 'churn']], hue='churn', palette='husl')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['label'] = le.fit_transform(df['gender'])

# %%
df[['churn','label']].head()
# Out:
#    churn  label
# 0      1      0
# 1      0      0
# 2      1      0
# 3      0      0
# 4      0      0

# %%
df['label'].value_counts()
# Out:
# label
# 1    5457
# 0    4543
# Name: count, dtype: int64

# %%
m_values = 5457
f_values = 45431
m_churn, f_churn = 0,0
for i in range(0, len(df)):
    if (df['churn'][i] == 1 and df['label'][i] == 1):
        m_churn += 1
    elif(df['churn'][i] == 1 and df['label'][i] == 0):
        f_churn += 1

# %%
print(f_churn, m_churn)
# Out:
# 1139 898

# %%
plt.bar(['m' , 'f'] , [m_churn, f_churn])
plt.title('Churn distribution for male and Female')
plt.show()

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn', 'label'],
#       dtype='object')

# %%
x = df[['credit_score', 'age', 'tenure',
       'balance', 'products_number', 'credit_card', 'active_member',
       'estimated_salary','label']]
y = df['churn']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.2, random_state = 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaling = StandardScaler()
scaling.fit(x_train)
# Out:
# StandardScaler()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
model.score(x_test, y_test)  #ACCURACY SCORE
# Out:
# 0.7835

# %%
preds = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
print(f"Accuracy Score:  {accuracy_score(y_test, preds)}")
print(f"Precision Score : {precision_score(y_test, preds)}")
# Out:
# Accuracy Score:  0.7835
# Precision Score : 0.3448275862068966

# %%
model.coef_
# Out:
# array([[-4.22187673e-03,  4.31154214e-02, -7.93672056e-02,
#          3.55826318e-06, -2.50650108e-02, -1.35308086e-02,
#         -6.19846963e-02, -1.36360374e-06, -4.05847219e-02]])

# %%
from sklearn.pipeline import make_pipeline #hyperparameter tuning

# %%
test_score = []
for lamda in np.arange(0.01, 100, 0.1):
    pipe = make_pipeline(StandardScaler() , LogisticRegression(C = 1/lamda))
    pipe.fit(x_train, y_train)
    scores = pipe.score(x_test, y_test)
    test_score.append(scores)

# %%
test_score
# Out:
# [0.802,
#  0.802,
#  0.802,
#  0.802,
#  0.802,
#  0.802,
#  0.802,
#  0.8025,
#  0.8025,
#  0.8025,
#  0.8025,
#  0.8025,
#  0.8025,
#  0.8025,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.8035,
#  0.804,
#  0.804,
#  0.804,
#  0.804,
#  0.804,
#  0.804,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.8035,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
#  0.803,
# ...

# %%
plt.plot(test_score)

# %%
np.argmax(test_score)
# Out:
# np.int64(23)
